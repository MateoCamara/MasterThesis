# %%
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary

webpage = "https://www.cdvl.org/wishlist.php" # edit me
id_ = "mcl"
password = "akAKak22"

# %%
driver = webdriver.Firefox()
driver.get(webpage)

# %%
sbox = driver.find_element_by_id("password")
sbox.send_keys(password)

# %%
sbox = driver.find_element_by_id("username")
sbox.send_keys(id_)

submit = driver.find_element_by_name("login")
submit.click()

# %%
import time
file = open("url_vqeg.txt", "w")

for i in range(1233, 1322): #1233-2290
    webpage = "https://www.cdvl.org/find-videos/requestdl.php?id="+str(i)
    print (webpage)
    driver.get(webpage)
    sbox = driver.find_element_by_class_name("nowrap")
    url = sbox.get_attribute('href')
    #time.sleep(2)
    file.write(url + '\n')
# Out:
# https://www.cdvl.org/find-videos/requestdl.php?id=1233
# https://www.cdvl.org/find-videos/requestdl.php?id=1234
# https://www.cdvl.org/find-videos/requestdl.php?id=1235
# https://www.cdvl.org/find-videos/requestdl.php?id=1236
# https://www.cdvl.org/find-videos/requestdl.php?id=1237
# https://www.cdvl.org/find-videos/requestdl.php?id=1238
# https://www.cdvl.org/find-videos/requestdl.php?id=1239
# https://www.cdvl.org/find-videos/requestdl.php?id=1240
# https://www.cdvl.org/find-videos/requestdl.php?id=1241
# https://www.cdvl.org/find-videos/requestdl.php?id=1242
# https://www.cdvl.org/find-videos/requestdl.php?id=1243
# https://www.cdvl.org/find-videos/requestdl.php?id=1244
# https://www.cdvl.org/find-videos/requestdl.php?id=1245
# https://www.cdvl.org/find-videos/requestdl.php?id=1246
# https://www.cdvl.org/find-videos/requestdl.php?id=1247
# https://www.cdvl.org/find-videos/requestdl.php?id=1248
# https://www.cdvl.org/find-videos/requestdl.php?id=1249
# ...

# %%
for i in range(1353, 1521): #1233-2290
    webpage = "https://www.cdvl.org/find-videos/requestdl.php?id="+str(i)
    print (webpage)
    driver.get(webpage)
    sbox = driver.find_element_by_class_name("nowrap")
    url = sbox.get_attribute('href')
    #time.sleep(2)
    file.write(url + '\n')
# Out:
# https://www.cdvl.org/find-videos/requestdl.php?id=1353
# https://www.cdvl.org/find-videos/requestdl.php?id=1354
# https://www.cdvl.org/find-videos/requestdl.php?id=1355
# https://www.cdvl.org/find-videos/requestdl.php?id=1356
# https://www.cdvl.org/find-videos/requestdl.php?id=1357
# https://www.cdvl.org/find-videos/requestdl.php?id=1358
# https://www.cdvl.org/find-videos/requestdl.php?id=1359
# https://www.cdvl.org/find-videos/requestdl.php?id=1360
# https://www.cdvl.org/find-videos/requestdl.php?id=1361
# https://www.cdvl.org/find-videos/requestdl.php?id=1362
# https://www.cdvl.org/find-videos/requestdl.php?id=1363
# https://www.cdvl.org/find-videos/requestdl.php?id=1364
# https://www.cdvl.org/find-videos/requestdl.php?id=1365
# https://www.cdvl.org/find-videos/requestdl.php?id=1366
# https://www.cdvl.org/find-videos/requestdl.php?id=1367
# https://www.cdvl.org/find-videos/requestdl.php?id=1368
# https://www.cdvl.org/find-videos/requestdl.php?id=1369
# ...

# %%
for i in range(1818, 2290): #1233-2290
    webpage = "https://www.cdvl.org/find-videos/requestdl.php?id="+str(i)
    print (webpage)
    driver.get(webpage)
    sbox = driver.find_element_by_class_name("nowrap")
    url = sbox.get_attribute('href')
    #time.sleep(2)
    file.write(url + '\n')
# Out:
# https://www.cdvl.org/find-videos/requestdl.php?id=1818
# https://www.cdvl.org/find-videos/requestdl.php?id=1819
# https://www.cdvl.org/find-videos/requestdl.php?id=1820
# https://www.cdvl.org/find-videos/requestdl.php?id=1821
# https://www.cdvl.org/find-videos/requestdl.php?id=1822
# https://www.cdvl.org/find-videos/requestdl.php?id=1823
# https://www.cdvl.org/find-videos/requestdl.php?id=1824
# https://www.cdvl.org/find-videos/requestdl.php?id=1825
# https://www.cdvl.org/find-videos/requestdl.php?id=1826
# https://www.cdvl.org/find-videos/requestdl.php?id=1827
# https://www.cdvl.org/find-videos/requestdl.php?id=1828
# https://www.cdvl.org/find-videos/requestdl.php?id=1829
# https://www.cdvl.org/find-videos/requestdl.php?id=1830
# https://www.cdvl.org/find-videos/requestdl.php?id=1831
# https://www.cdvl.org/find-videos/requestdl.php?id=1832
# https://www.cdvl.org/find-videos/requestdl.php?id=1833
# https://www.cdvl.org/find-videos/requestdl.php?id=1834
# ...

# %%
# !cat url_vqeg.txt
# Out:
# http://www.cdvl.org/download.php?id=1233&t=fv&uid=9666&token=129f60dd-7ca545c264b7fd24774a6ba71433cdf67f5b9619
# http://www.cdvl.org/download.php?id=1234&t=fv&uid=9666&token=129f60de-280fe24cb80c257448ad0332962c3a8750bdba59
# http://www.cdvl.org/download.php?id=1235&t=fv&uid=9666&token=129f60de-4528b8d73cacf5070f072a7b1ff9530f77b04bd5
# http://www.cdvl.org/download.php?id=1236&t=fv&uid=9666&token=129f60df-7914a869a8647dd81b073d15986bc8c97c3c6a9b
# http://www.cdvl.org/download.php?id=1237&t=fv&uid=9666&token=129f60df-2e0c11fd398391f352809f396be0b5ebdc47bd58
# http://www.cdvl.org/download.php?id=1238&t=fv&uid=9666&token=129f60e0-1096c1eb29de828913b4f12d44cb6dfde4bd6e98
# http://www.cdvl.org/download.php?id=1239&t=fv&uid=9666&token=129f60e0-58814d1fecdc3add52e15250ad5933a2abf5f366
# http://www.cdvl.org/download.php?id=1240&t=fv&uid=9666&token=129f60e1-7576f373cef9d7fd729b815ff003dabd75bea0a8
# ...
